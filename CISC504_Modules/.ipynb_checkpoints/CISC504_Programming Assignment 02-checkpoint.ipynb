# %% [markdown]
#  <h1 style="text-align:center">Harrisburg University of Science & Technology</h1>
#     <h2 style="text-align:center">CISC 504 Principles of Programming Languages </h2>
#     <h3 style="text-align:center">Assignment 2: Python Structures</h3>

# %% [markdown]
# <h3> (1) Employee Data Representation: </h3>
#
# 1. You are going to store table data using a nested list,
# 2. Imagine this: you are currently working in an IT company and are given the following list of employees,
# 3. You are asked by your manager to use Python to store this data for further company use.
# 4. The data "employee.png"is provided to you in by your company is shown below:

# %%
from IPython.display import Image
Image(filename='employee.png')

# %% [markdown]
# # A6 Instructions
# 1. Open a new Jupyter Notebook.
# 2. Create a list and assign it to employees.
# 3. Create three nested lists in employees to store the information of each employee, respectively.
# 4. Print the employees variable.
# 5. Print the details of all employees in a presentable format.
# 6. Print only the details of Lisa Crawford.

# %% [markdown]
# By printing the details in a presentable format, you should get the following output:

# %%
from IPython.display import Image
Image(filename='Lisa.png')

# %% [markdown]
# # A6 Your Solution:

# %% [markdown]
# # A7 Problem:
# Remember the employee dataset you previously stored using a nested list?
# Now instead of nested lists, you need to store it and access our data more effectively using <b>lists and dictionaries</b>

# %% [markdown]
# # A7 Instructions
# 1. Open a Jupyter notebook (you can create a new one or use an existing one).
# 2. Create a list named employees.
# 3. Create three dictionary objects inside employees to store the information of each employee.
# 4. Print the employees variable.
# 5. Print the details of all employees in a presentable format.
# 6. Print only the details of Sujan Patel.

# %% [markdown]
# By printing the details in a presentable format, you should get the following output:

# %%
from IPython.display import Image
Image(filename='Sujan.png')

# %% [markdown]
# # A7 Your Solution:

# %% [markdown]
# # Execution & Results
# - <b>Provide your 5-minutes Walk-through Recording (A link for a YouTube recordings) for both problems

# %% [markdown]
# ### An example from a fellow student (Yan Chu)

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('1vCtUeypmMo')
